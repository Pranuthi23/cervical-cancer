# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#loading the dataset into df
df = pd.read_csv('C:\\Users\\pranu\\OneDrive\\Desktop\\data.csv', na_values='?')

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 36 columns):
# Age                                   858 non-null int64
# Number of sexual partners             832 non-null float64
# First sexual intercourse              851 non-null float64
# Num of pregnancies                    802 non-null float64
# Smokes                                845 non-null float64
# Smokes (years)                        845 non-null float64
# Smokes (packs/year)                   845 non-null float64
# Hormonal Contraceptives               750 non-null float64
# Hormonal Contraceptives (years)       750 non-null float64
# IUD                                   741 non-null float64
# IUD (years)                           741 non-null float64
# STDs                                  753 non-null float64
# STDs (number)                         753 non-null float64
# STDs:condylomatosis                   753 non-null float64
# ...

# %%
np.round(df.isnull().sum()/df.shape[0]*100).sort_values().plot(kind = 'bar')

# %%
# As the last two columns represent large number of nan values, they contribute very less to the output variable
df=df.drop(['STDs: Time since first diagnosis','STDs: Time since last diagnosis'],axis=1)

# %%
df.describe()
# Out:
#               Age  Number of sexual partners  First sexual intercourse  \
# count  858.000000                 832.000000                851.000000
# mean    26.820513                   2.527644                 16.995300
# std      8.497948                   1.667760                  2.803355
# min     13.000000                   1.000000                 10.000000
# 25%     20.000000                   2.000000                 15.000000
# 50%     25.000000                   2.000000                 17.000000
# 75%     32.000000                   3.000000                 18.000000
# max     84.000000                  28.000000                 32.000000
#
#        Num of pregnancies      Smokes  Smokes (years)  Smokes (packs/year)  \
# count          802.000000  845.000000      845.000000           845.000000
# mean             2.275561    0.145562        1.219721             0.453144
# std              1.447414    0.352876        4.089017             2.226610
# ...

# %%
df['Biopsy'].value_counts()
sns.countplot(df['Biopsy'],label="Count")

# %%
df=df.drop(['Hinselmann','Schiller','Citology'],axis=1)

# %%
correlationMap = df.corr()
plt.figure(figsize=(40,40))
sns.set(font_scale=1)
hm = sns.heatmap(correlationMap, annot=True)
plt.show()

# %%
categorical=['Smokes','Hormonal Contraceptives','IUD','STDs','STDs:condylomatosis','STDs:cervical condylomatosis',
             'STDs:vaginal condylomatosis','STDs:vulvo-perineal condylomatosis','STDs:syphilis',
             'STDs:pelvic inflammatory disease','STDs:genital herpes','STDs:molluscum contagiosum','STDs:AIDS',
             'STDs:HIV','STDs:Hepatitis B','STDs:HPV','Dx:Cancer','Dx:CIN','Dx:HPV','Dx']

# %%
numerical = ['Age','Number of sexual partners','First sexual intercourse','Num of pregnancies','Smokes (years)',
             'Smokes (packs/year)','Hormonal Contraceptives (years)','IUD (years)','STDs (number)',
             'STDs: Number of diagnosis']

# %%
#imputation
from sklearn.preprocessing import Imputer,StandardScaler,MinMaxScaler
# im = Imputer(missing_values = np.nan,strategy = "median")
# X = im.fit_transform(X)
for i in numerical:
    df[i] = df[i].fillna(df[i].median())
for i in categorical:
    df[i] = df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# Age                                   0
# Number of sexual partners             0
# First sexual intercourse              0
# Num of pregnancies                    0
# Smokes                                0
# Smokes (years)                        0
# Smokes (packs/year)                   0
# Hormonal Contraceptives               0
# Hormonal Contraceptives (years)       0
# IUD                                   0
# IUD (years)                           0
# STDs                                  0
# STDs (number)                         0
# STDs:condylomatosis                   0
# STDs:cervical condylomatosis          0
# STDs:vaginal condylomatosis           0
# STDs:vulvo-perineal condylomatosis    0
# STDs:syphilis                         0
# STDs:pelvic inflammatory disease      0
# STDs:genital herpes                   0
# STDs:molluscum contagiosum            0
# STDs:AIDS                             0
# STDs:HIV                              0
# ...

# %%
correlation = df.corr()
k = 16
correlations = correlation.nlargest(k, 'Biopsy')['Biopsy'].index
M = df[correlations].corr()
plt.figure(figsize=(20,20))
sns.set(font_scale=1)
H = sns.heatmap(M, annot=True)
plt.show()

# %%
g = sns.PairGrid(df,y_vars=['Hormonal Contraceptives'],x_vars= ['Biopsy'])
g.map(sns.barplot, palette="pastel")

# %%
X = df.iloc[:, 0:30].values
y = df.iloc[:, 30].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 12)
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
classifier = DecisionTreeClassifier(criterion='gini', max_leaf_nodes= None,min_samples_leaf=14, min_samples_split=2 ,
                                    random_state = 12)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# 0.937984496124031
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       258
#            1       0.00      0.00      0.00         0
#
#    micro avg       0.94      0.94      0.94       258
#    macro avg       0.50      0.47      0.48       258
# weighted avg       1.00      0.94      0.97       258
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %%
df.describe()
# Out:
#               Age  Number of sexual partners  First sexual intercourse  \
# count  858.000000                 858.000000                858.000000
# mean    26.820513                   2.511655                 16.995338
# std      8.497948                   1.644759                  2.791883
# min     13.000000                   1.000000                 10.000000
# 25%     20.000000                   2.000000                 15.000000
# 50%     25.000000                   2.000000                 17.000000
# 75%     32.000000                   3.000000                 18.000000
# max     84.000000                  28.000000                 32.000000
#
#        Num of pregnancies      Smokes  Smokes (years)  Smokes (packs/year)  \
# count          858.000000  858.000000      858.000000           858.000000
# mean             2.257576    0.143357        1.201241             0.446278
# std              1.400981    0.350641        4.060623             2.210351
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %%
m1 = LogisticRegression(C=4,penalty='l2')
m1 = m1.fit(X_train, y_train)
y_pred = m1.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_test, y_pred))
# Out:
# 0.937984496124031
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       242
#            1       0.50      0.06      0.11        16
#
#    micro avg       0.94      0.94      0.94       258
#    macro avg       0.72      0.53      0.54       258
# weighted avg       0.91      0.94      0.91       258
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
m1 = LogisticRegression(C=3,penalty='l1')
m1.fit(X_train, y_train)
y_pred = m1.predict(X_test)
print(accuracy_score(y_pred,y_test))
# Out:
# 0.9341085271317829
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
knn = KNeighborsClassifier(n_neighbors = 5,p = 2,metric = 'minkowski')
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_test, y_pred))
# Out:
# 0.9263565891472868
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       242
#            1       0.00      0.00      0.00        16
#
#    micro avg       0.93      0.93      0.93       258
#    macro avg       0.47      0.49      0.48       258
# weighted avg       0.88      0.93      0.90       258

# %%
from sklearn.cluster import KMeans
km = KMeans()
y_km = km.fit_predict(X_test)
print(accuracy_score(y_km,y_test))
print(classification_report(y_test, y_km))
# Out:
# 0.2054263565891473
#               precision    recall  f1-score   support
#
#            0       0.92      0.20      0.33       242
#            1       0.03      0.25      0.06        16
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#
#    micro avg       0.21      0.21      0.21       258
#    macro avg       0.12      0.06      0.05       258
# weighted avg       0.87      0.21      0.32       258
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %%
Rf = RandomForestClassifier(max_depth=5, n_estimators=10,max_features=1,n_jobs=10)
Rf.fit(X_train, y_train)
y_pred = Rf.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_test, y_pred))
# Out:
# 0.937984496124031
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       242
#            1       0.00      0.00      0.00        16
#
#    micro avg       0.94      0.94      0.94       258
#    macro avg       0.47      0.50      0.48       258
# weighted avg       0.88      0.94      0.91       258
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\pranu\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
clf = GaussianNB(priors = None)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_test, y_pred))
# Out:
# 0.08527131782945736
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.05       242
#            1       0.06      1.00      0.12        16
#
#    micro avg       0.09      0.09      0.09       258
#    macro avg       0.53      0.51      0.08       258
# weighted avg       0.94      0.09      0.05       258

# %%
s = SVC(kernel="rbf", C=100,gamma=15)
s.fit(X_train, y_train)
y_pred = s.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_test, y_pred))
# Out:
# 0.9108527131782945
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       242
#            1       0.11      0.06      0.08        16
#
#    micro avg       0.91      0.91      0.91       258
#    macro avg       0.53      0.51      0.52       258
# weighted avg       0.89      0.91      0.90       258
